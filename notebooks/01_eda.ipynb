# %%
import pandas as pd

df = pd.read_csv("../data_raw/games_raw.csv")
df.head()
df.info()
print("shape: " + str(df.shape))
df.describe()

# dupes = df[df.duplicated(subset=["id"], keep=False)].sort_values("id")
# print(dupes.head(20))
# print("Number of duplicated ids:", dupes["id"].nunique())
# print("Total duplicate rows:", len(dupes))
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 11279  061LCiAb   True  1.396113e+12  1.396114e+12     66           draw
# 10570  061LCiAb   True  1.396113e+12  1.396114e+12     66           draw
# 12208  079kHDqh   True  1.504113e+12  1.504113e+12     32         resign
# 720    079kHDqh   True  1.504110e+12  1.504110e+12     32         resign
# 3882   07e0uVvn   True  1.491950e+12  1.491960e+12     35           mate
# 18642  07e0uVvn   True  1.491955e+12  1.491955e+12     35           mate
# 13478  07qaUepw   True  1.504213e+12  1.504213e+12     47         resign
# 11387  07qaUepw   True  1.504213e+12  1.504213e+12     47         resign
# 18317  09fzI0ta   True  1.500985e+12  1.500986e+12     55         resign
# 5413   09fzI0ta   True  1.500990e+12  1.500990e+12     55         resign
# 12243  0CCos4zy   True  1.503172e+12  1.503173e+12     62         resign
# 808    0CCos4zy   True  1.503170e+12  1.503170e+12     62         resign
# ...
